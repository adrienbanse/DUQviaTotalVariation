# %%
import propagation_methods as propag
import grid_generation as grid
import bounds_common as bounds
import barriers as barriers
import probability_mass_computation as proba
import plot_methods as plot

import numpy as np

# %% [markdown]
# ### **The polynomial case**
#
# In this experiement, $x_0$ follows a Gaussian distribution ($x_0 \sim \mathcal{N}(\mu_{0}, \Sigma_{0})$), and the system is polynomial following XXX.
#
# We aim to compute GMM approximations $\hat{p}(x_t)$ for $5$ time steps, as well as bounds on their TV distances to the true distributions $p(x_t)$.
#
# **Numerical note**: The theory related to this experiement does NOT demand that those Gaussians should have uncorrelated components. However, our current code implementation does assume that.

# %% [markdown]
# ##### 1) Defining system parameters

# %%
METHOD = 'polynomial'

h = 0.05

params = [h]

# %%
#Initial distribution
sigma = 0.002

mean_initial_state = np.array([1, 1])
var_initial_state = np.array([sigma, sigma]) #Assumes uncorrelation (this could be relaxed in further upgrades)

#Noise structure
sigma_noise = 0.01

mean_noise = [0, 0]
var_noise = np.array([sigma_noise, sigma_noise/2]) #Assumes uncorrelation (this could be relaxed in further upgrades)

#Steps ahead for prediction
n_steps_ahead = 7

# %%
unbounded_region = np.array([[np.inf, np.inf], [np.inf, np.inf]]) #a representation choice for the unbounded region

# %%
colors = ['Purples', 'Blues', 'Oranges', 'YlOrBr', 'YlOrRd', 
          'OrRd', 'PuRd', 'RdPu', 'BuPu', 'GnBu', 
          'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']

# %% [markdown]
# ##### 2) Monte Carlo simulation of the system
#
# We run a MC simulation for the system above in order to understand its (probabilistic) behavior.
#
# Note: We also add a representation for an unsafe set (red square) which will later motivate safety discussions.

# %%
barriers_list = barriers.createBarrier(np.array([[1.5, 2.0], [2.0, 4.0]]))
barrier = barriers_list[0]

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# C:\Users\efigueiredomot\AppData\Local\Temp\ipykernel_4716\2522582876.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

n_simulations = 10_000
mc_hitting_proba = []

fig, ax = plt.subplots()

rect = Rectangle(barrier[0], barrier[1][0] - barrier[0][0], barrier[1][1] - barrier[0][1], 
                    edgecolor = 'red', facecolor = 'lightcoral', fill=True, lw=1, alpha=0.7, label = 'Unsafe set')
ax.add_patch(rect)

for t in range(n_steps_ahead + 1):
    if t == 0:
        states = propag.getInitialState(mean_initial_state, var_initial_state, n_simulations)
    else:
        states = propag.stateOneStepEvolution(states, mean_noise, var_noise, METHOD, params)
    
    #Plot samples
    plt.hist2d(states[:, 0], states[:, 1], bins=100, cmap=colors[t], alpha=0.8, cmin=0.1)

    #Compute hitting probability
    hitting_proba = barriers.hittingProbabilityMC(states, barrier)
    mc_hitting_proba.append(hitting_proba)

plt.legend(loc='lower right')

plt.xlim(-1, 5)
plt.ylim(-1, 15)
plt.xlabel('State[0]')
plt.ylabel('State[1]')
plt.grid(True)
plt.show()
# Out:
# Hitting proba: 0.0
# Hitting proba: 0.0
# Hitting proba: 0.0043
# Hitting proba: 0.0983
# Hitting proba: 0.2367
# Hitting proba: 0.0003
# Hitting proba: 0.0
# Hitting proba: 0.0

# %% [markdown]
# ##### Influence of noise variance

# %%
# n_samples = 10_000

# min_proportion = 0.02
# min_size = 0.05
# n_refinements = 5

# tv_bounds = [0.0]
# gmm_hitting_proba = [0.0]

# variance_noise_options = [0.0001, 0.001, 0.01, 0.1, 1.0]

# for var_value in variance_noise_options:

#     var = np.array([var_value, var_value])

#     print('SIMULATION FOR VAR =  ', var_value)

#     for t in range(2):

#         print('TIME STEP', t+1)

#         if t == 0:
#             hat_gmm = [np.array([1.0]), np.array([mean_initial_state]), var_initial_state]
#         else:
#             means_gmm = propag.propagateSignatures(signatures, METHOD, params)
#             hat_gmm = [double_hat_proba, means_gmm, var_noise]


#         samples = propag.sampleFromGMM(n_samples, hat_gmm[0], hat_gmm[1], hat_gmm[2])
#         plt.hist2d(samples[:, 0], samples[:, 1], bins=100, cmap=colors[t], alpha=0.8, cmin=0.1)

#         if t < n_steps_ahead:

#             vertice_lower, vertice_upper = grid.findMinMaxPoints(samples)

#             hpr = np.array([vertice_lower, vertice_upper])

#             outer_signature = grid.computeOuterPoint(hpr)

#             regions = np.array(grid.subdivideRegion(hpr, samples, min_proportion, min_size))
#             print('Number of regions: ', len(regions))

#             signatures = grid.placeSignatures(regions)

#             double_hat_proba = proba.computeSignatureProbabilitiesInParallel(regions, hat_gmm[1], hat_gmm[2], hat_gmm[0])

#             regions, signatures = grid.addUnboundedRepresentations(regions, unbounded_region, signatures, outer_signature)

#             tv_bound, contributions = bounds.computeUpperBoundForTVWithMax(signatures, regions, double_hat_proba, var, METHOD, params)

#             for r in range(n_refinements):

#                 regions, signatures = grid.refineRegions(regions, signatures, contributions, 1e-7)
#                 regions = regions[:-1]
#                 signatures = signatures[:-1]
#                 double_hat_proba = proba.computeSignatureProbabilitiesInParallel(regions, hat_gmm[1], hat_gmm[2], hat_gmm[0])
#                 regions, signatures = grid.addUnboundedRepresentations(regions, unbounded_region, signatures, outer_signature)
#                 print('Number of regions: ', len(regions))

#                 tv_bound, contributions = bounds.computeUpperBoundForTVWithMax(signatures, regions, double_hat_proba, var, METHOD, params)

#             tv_bounds.append(tv_bound)

# %% [markdown]
# ##### TV bounds

# %%
n_samples = 10_000

min_proportion = 0.01
min_size = 0.01
n_refinements = 5

tv_bounds = [0.0]
gmm_hitting_proba = [0.0]


fig, ax = plt.subplots()

rect = Rectangle(barrier[0], barrier[1][0] - barrier[0][0], barrier[1][1] - barrier[0][1], 
                    edgecolor = 'red', facecolor = 'lightcoral', fill=True, lw=1, alpha=0.7, label = 'Unsafe set')
ax.add_patch(rect)

for t in range(n_steps_ahead + 1):

    if t == 0:
        hat_gmm = [np.array([1.0]), np.array([mean_initial_state]), var_initial_state]
    else:
        means_gmm = propag.propagateSignatures(signatures, METHOD, params)
        hat_gmm = [double_hat_proba, means_gmm, var_noise]

        #Compute hitting probability
        proba_barrier = proba.gmmProbabilityMassInsideRegion(double_hat_proba, means_gmm, var_noise, barrier)
        gmm_hitting_proba.append(proba_barrier)


    samples = propag.sampleFromGMM(n_samples, hat_gmm[0], hat_gmm[1], hat_gmm[2])
    plt.hist2d(samples[:, 0], samples[:, 1], bins=100, cmap=colors[t], alpha=0.8, cmin=0.1)

    if t < n_steps_ahead:

        vertice_lower, vertice_upper = grid.findMinMaxPoints(samples)

        hpr = np.array([vertice_lower, vertice_upper])

        outer_signature = grid.computeOuterPoint(hpr)

        regions = np.array(grid.subdivideRegion(hpr, samples, min_proportion, min_size))

        signatures = grid.placeSignatures(regions)

        double_hat_proba = proba.computeSignatureProbabilitiesInParallel(regions, hat_gmm[1], hat_gmm[2], hat_gmm[0])

        regions, signatures = grid.addUnboundedRepresentations(regions, unbounded_region, signatures, outer_signature)

        tv_bound, contributions = bounds.computeUpperBoundForTVWithMax(signatures, regions, double_hat_proba, var_noise, METHOD, params)

        for r in range(n_refinements):

            regions, signatures = grid.refineRegions(regions, signatures, contributions, 1e-7)
            regions = regions[:-1]
            signatures = signatures[:-1]
            double_hat_proba = proba.computeSignatureProbabilitiesInParallel(regions, hat_gmm[1], hat_gmm[2], hat_gmm[0])
            regions, signatures = grid.addUnboundedRepresentations(regions, unbounded_region, signatures, outer_signature)
            print('Number of regions: ', len(regions))

            tv_bound, contributions = bounds.computeUpperBoundForTVWithMax(signatures, regions, double_hat_proba, var_noise, METHOD, params)

        tv_bounds.append(tv_bound)
    

plt.legend(loc='lower right')

plt.xlim(-1, 5)
plt.ylim(-1, 15)
plt.xlabel('State[0]')
plt.ylabel('State[1]')
plt.grid(True)
plt.show()
# Out:
# Function 'computeSignatureProbabilitiesInParallel' executed in 0.7436s
# TV bound at propag step: 0.07539140104057868
# Function 'computeSignatureProbabilitiesInParallel' executed in 0.4831s
# Number of regions:  821
# TV bound at propag step: 0.03813567756426069
# Function 'computeSignatureProbabilitiesInParallel' executed in 0.5636s
# Number of regions:  3275
# TV bound at propag step: 0.0193244847897412
# Function 'computeSignatureProbabilitiesInParallel' executed in 0.5496s
# Number of regions:  13058
# TV bound at propag step: 0.009895572369562665
# Function 'computeSignatureProbabilitiesInParallel' executed in 0.6849s
# Number of regions:  50888
# TV bound at propag step: 0.00519352310532667
# Function 'computeSignatureProbabilitiesInParallel' executed in 0.8489s
# Number of regions:  85721
# TV bound at propag step: 0.003913716075378588
# 9.151235303845718e-16
# Function 'computeSignatureProbabilitiesInParallel' executed in 0.9543s
# TV bound at propag step: 0.1603596891082619
# Function 'computeSignatureProbabilitiesInParallel' executed in 2.3831s
# Number of regions:  785
# TV bound at propag step: 0.08260102963654588
# Function 'computeSignatureProbabilitiesInParallel' executed in 8.4389s
# Number of regions:  3134
# TV bound at propag step: 0.041814372981188744
# Function 'computeSignatureProbabilitiesInParallel' executed in 43.6611s
# Number of regions:  12497
# TV bound at propag step: 0.021146790071754434
# Function 'computeSignatureProbabilitiesInParallel' executed in 186.6109s
# Number of regions:  49586
# TV bound at propag step: 0.01078077712342858
# Function 'computeSignatureProbabilitiesInParallel' executed in 492.7487s
# Number of regions:  158921
# TV bound at propag step: 0.0060617327552468315
# 0.0041930757848484155
# Function 'computeSignatureProbabilitiesInParallel' executed in 2.4682s
# TV bound at propag step: 0.2245484438523426
# Function 'computeSignatureProbabilitiesInParallel' executed in 7.1108s
# Number of regions:  881
# TV bound at propag step: 0.1174775908979398
# Function 'computeSignatureProbabilitiesInParallel' executed in 26.2549s
# Number of regions:  3521
# TV bound at propag step: 0.059711663353107396
# Function 'computeSignatureProbabilitiesInParallel' executed in 103.4472s
# Number of regions:  14072
# TV bound at propag step: 0.030156660771823624
# Function 'computeSignatureProbabilitiesInParallel' executed in 408.0583s
# Number of regions:  55817
# TV bound at propag step: 0.015293811677934427
# Function 'computeSignatureProbabilitiesInParallel' executed in 1505.2682s
# Number of regions:  198110
# TV bound at propag step: 0.00813574112982255
# 0.10288480268354568
# Function 'computeSignatureProbabilitiesInParallel' executed in 3.3793s
# TV bound at propag step: 0.3173511331726903
# Function 'computeSignatureProbabilitiesInParallel' executed in 9.8744s
# Number of regions:  881
# TV bound at propag step: 0.16773357783303258
# Function 'computeSignatureProbabilitiesInParallel' executed in 36.3072s
# Number of regions:  3521
# TV bound at propag step: 0.08540116493976915
# Function 'computeSignatureProbabilitiesInParallel' executed in 143.4690s
# Number of regions:  14069
# TV bound at propag step: 0.04305306725512114
# Function 'computeSignatureProbabilitiesInParallel' executed in 617.5382s
# Number of regions:  55892
# TV bound at propag step: 0.02172445119825007
# Function 'computeSignatureProbabilitiesInParallel' executed in 2250.9196s
# Number of regions:  214592
# TV bound at propag step: 0.011121245000840095
# 0.23719724098943532
# Function 'computeSignatureProbabilitiesInParallel' executed in 3.9711s
# TV bound at propag step: 0.40546648600662083
# Function 'computeSignatureProbabilitiesInParallel' executed in 11.2456s
# Number of regions:  869
# TV bound at propag step: 0.22511912226489286
# Function 'computeSignatureProbabilitiesInParallel' executed in 41.6114s
# Number of regions:  3473
# TV bound at propag step: 0.11828721334811453
# Function 'computeSignatureProbabilitiesInParallel' executed in 166.1767s
# Number of regions:  13859
# TV bound at propag step: 0.06023172514419733
# Function 'computeSignatureProbabilitiesInParallel' executed in 659.2390s
# Number of regions:  55157
# TV bound at propag step: 0.030426073106082016
# Function 'computeSignatureProbabilitiesInParallel' executed in 2559.9377s
# Number of regions:  214202
# TV bound at propag step: 0.015489669951857268
# 0.00030851179895838423
# Function 'computeSignatureProbabilitiesInParallel' executed in 3.7785s
# TV bound at propag step: 0.5599693940388387
# Function 'computeSignatureProbabilitiesInParallel' executed in 11.0695s
# Number of regions:  845
# TV bound at propag step: 0.32769404044112865
# Function 'computeSignatureProbabilitiesInParallel' executed in 41.4098s
# Number of regions:  3377
# TV bound at propag step: 0.17629944026226527
# Function 'computeSignatureProbabilitiesInParallel' executed in 165.7775s
# Number of regions:  13481
# TV bound at propag step: 0.09052533312091711
# Function 'computeSignatureProbabilitiesInParallel' executed in 659.6762s
# Number of regions:  53660
# TV bound at propag step: 0.045723371394366066
# Function 'computeSignatureProbabilitiesInParallel' executed in 2594.1323s
# Number of regions:  210935
# TV bound at propag step: 0.023077676157705826
# 0.0
# Function 'computeSignatureProbabilitiesInParallel' executed in 3.6947s
# TV bound at propag step: 0.6999610392683658
# Function 'computeSignatureProbabilitiesInParallel' executed in 10.9342s
# Number of regions:  833
# TV bound at propag step: 0.43134006814912546
# Function 'computeSignatureProbabilitiesInParallel' executed in 41.4882s
# Number of regions:  3326
# TV bound at propag step: 0.23928528992317843
# Function 'computeSignatureProbabilitiesInParallel' executed in 163.3275s
# Number of regions:  13268
# TV bound at propag step: 0.12509136229137816
# Function 'computeSignatureProbabilitiesInParallel' executed in 654.0853s
# Number of regions:  52862
# TV bound at propag step: 0.06356990810184955
# Function 'computeSignatureProbabilitiesInParallel' executed in 2577.5450s
# Number of regions:  209018
# TV bound at propag step: 0.03210723286778896
# 0.0

# %% [markdown]
# ##### TV contribution per region

# %%
contributions = np.array(contributions)
contributions = np.sort(contributions)
plt.plot(contributions)

# %%
plt.plot(np.cumsum(contributions))

# %%
import matplotlib.pyplot as plt

def draw_square(x_min, y_min, x_max, y_max):
    plt.plot([x_min, x_max, x_max, x_min, x_min], [y_min, y_min, y_max, y_max, y_min], color='blue')

def plot_regions(regions):
    for region in regions:
        x_min, y_min = region[0]
        x_max, y_max = region[1]
        draw_square(x_min, y_min, x_max, y_max)
    plt.xlabel('State[0]')
    plt.ylabel('State[1]')
    plt.grid(True)
    plt.axis('equal')  # Set equal aspect ratio
    plt.show()

# %%
plot_regions(regions)

# %% [markdown]
# ##### Compare hitting probabilities

# %%
#Compute TV bounds
tv_bounds_cumul = np.cumsum(tv_bounds)

plt.style.use("seaborn")

# Plotting
plt.scatter(range(len(mc_hitting_proba)), mc_hitting_proba, color='green', alpha = 0.9, label = f'Monte Carlo ({n_simulations:.0e} samples)', zorder=3)
plt.scatter(range(len(gmm_hitting_proba)), gmm_hitting_proba, color='black', alpha = 0.9, marker='s', label = f'GMM approx. ({n_samples:.0e} samples)', zorder=2)

# Adding error bars for gmm_probas
plt.errorbar(range(len(gmm_hitting_proba)), gmm_hitting_proba, yerr = tv_bounds_cumul, fmt='none', color='black', alpha = 0.9, capsize=5, label='TV bounds', zorder=1)

plt.ylim(0, 1)
plt.xticks(range(len(mc_hitting_proba)))

plt.xlabel('Time step')
plt.ylabel('Hitting probability')
plt.legend()
plt.show()
# Out:
# C:\Users\efigueiredomot\AppData\Local\Temp\ipykernel_4716\1569244730.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %% [markdown]
# ##### TV bounds

# %%
tv_bounds_cumul
# Out:
# array([0.        , 0.00391372, 0.00997545, 0.01811119, 0.02923243,
#        0.0447221 , 0.06779978, 0.09990701])
